# %%
import pandas as pd

# %%
df=pd.read_csv('output.csv')

# %%
df
# Out:
#                          city country        date      lat       lon  \
# 0    São Gabriel da Cachoeira      BR  1631344798  -0.1303  -67.0892
# 1                     Rikitea      PF  1631344799 -23.1203 -134.9692
# 2                   Ilulissat      GL  1631344800  69.2167  -51.1000
# 3                     Ushuaia      AR  1631344801 -54.8000  -68.3000
# 4                  Bredasdorp      ZA  1631344803 -34.5322   20.0403
# ..                        ...     ...         ...      ...       ...
# 537                 Ugoofaaru      MV  1631345278   5.6667   73.0000
# 538                  Bien Hoa      VN  1631345279  10.9500  106.8167
# 539                     Seoul      KR  1631345006  37.5683  126.9778
# 540                 Pemangkat      ID  1631345281   1.1667  108.9667
# 541           Lázaro Cárdenas      MX  1631345283  17.9583 -102.2000
#
#      max_temp  humidity  cloudiness  wind_speed
# 0       22.12        99         100        0.79
# ...

# %%
new_df=df.to_html()
print(new_df)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>city</th>
#       <th>country</th>
#       <th>date</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>max_temp</th>
#       <th>humidity</th>
#       <th>cloudiness</th>
#       <th>wind_speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>São Gabriel da Cachoeira</td>
#       <td>BR</td>
#       <td>1631344798</td>
#       <td>-0.1303</td>
#       <td>-67.0892</td>
#       <td>22.12</td>
#       <td>99</td>
#       <td>100</td>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Rikitea</td>
#       <td>PF</td>
#       <td>1631344799</td>
#       <td>-23.1203</td>
#       <td>-134.9692</td>
#       <td>23.34</td>
#       <td>74</td>
#       <td>100</td>
#       <td>5.36</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Ilulissat</td>
#       <td>GL</td>
#       <td>1631344800</td>
# ...

# %%
html_table=new_df

# %%
text_file = open("../HTML/data.html", "w")
text_file.write(html_table)
text_file.close()
